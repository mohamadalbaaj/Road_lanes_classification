# %% [markdown]
# @misc{chollet2015keras,
#   title={Keras},
#   author={Chollet, Fran\c{c}ois and others},
#   year={2015},
#   howpublished={\url{https://keras.io}},
# }

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Define the path

# %%
path2data = os.path.join(os.getcwd(), "dataset", "train_data")
print(path2data)
# Out:
# h:\Approach2_sol\dataset\train_data

# %% [markdown]
# Split the data (80% train, 20% Validation) and resizing the images

# %%
image_size = (64, 64)
batch_size = 32

train_ds, val_ds = tf.keras.utils.image_dataset_from_directory(
    path2data,
    validation_split=0.20,
    subset="both",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 1425 files belonging to 6 classes.
# Using 1140 files for training.
# Using 285 files for validation.

# %% [markdown]
# Visualize the data

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %% [markdown]
# Data augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.05),
    ]
)

# %% [markdown]
# Visualize the augmented data

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
augmented_train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y))

# %%
# Apply `data_augmentation` to the training images.
train_ds = train_ds.map(
    lambda img, label: (data_augmentation(img), label),
    num_parallel_calls=tf.data.AUTOTUNE,
)
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# The model

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    # Entry block
    x = layers.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(128, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=6)
#keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# Running the code

# %%
epochs = 40
num_classes=6

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.keras"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)

def preprocess_data(image, label):
    image = data_augmentation(image)  # Apply data augmentation
    label = tf.one_hot(label, depth=num_classes)  # Convert label to one-hot encoded using TensorFlow operation
    return image, label

train_ds = train_ds.map(lambda x, y: preprocess_data(x, y))
val_ds = val_ds.map(lambda x, y: preprocess_data(x, y))


model.fit(
    train_ds,
    epochs=epochs,
    callbacks=callbacks,
    validation_data=val_ds,
)

evaluation = model.evaluate(train_ds)
print("Validation Loss:", evaluation[0])
print("Validation Accuracy:", evaluation[1])
# Out:
# Epoch 1/40
# 36/36 [==============================] - 35s 876ms/step - loss: 1.5473 - accuracy: 0.4079 - val_loss: 1.8262 - val_accuracy: 0.0877
# Epoch 2/40
# 36/36 [==============================] - 31s 849ms/step - loss: 1.3770 - accuracy: 0.4746 - val_loss: 1.8566 - val_accuracy: 0.0877
# Epoch 3/40
# 36/36 [==============================] - 30s 839ms/step - loss: 1.2424 - accuracy: 0.5158 - val_loss: 1.9131 - val_accuracy: 0.0877
# Epoch 4/40
# 36/36 [==============================] - 33s 911ms/step - loss: 1.1972 - accuracy: 0.5430 - val_loss: 2.0460 - val_accuracy: 0.0877
# Epoch 5/40
# 36/36 [==============================] - 29s 806ms/step - loss: 1.1660 - accuracy: 0.5544 - val_loss: 2.2317 - val_accuracy: 0.0877
# Epoch 6/40
# 36/36 [==============================] - 30s 836ms/step - loss: 1.1099 - accuracy: 0.5693 - val_loss: 2.2770 - val_accuracy: 0.1579
# Epoch 7/40
# 36/36 [==============================] - 30s 837ms/step - loss: 1.1144 - accuracy: 0.5807 - val_loss: 2.3318 - val_accuracy: 0.1579
# Epoch 8/40
# 36/36 [==============================] - 31s 862ms/step - loss: 1.0759 - accuracy: 0.6018 - val_loss: 2.4650 - val_accuracy: 0.0877
# 36/36 [==============================] - 29s 817ms/step - loss: 0.7331 - accuracy: 0.7211 - val_loss: 1.6861 - val_accuracy: 0.5123
# Epoch 27/40
# 36/36 [==============================] - 31s 856ms/step - loss: 0.7448 - accuracy: 0.7149 - val_loss: 1.5138 - val_accuracy: 0.5228
# Epoch 28/40
# 36/36 [==============================] - 29s 799ms/step - loss: 0.7090 - accuracy: 0.7342 - val_loss: 1.1489 - val_accuracy: 0.6246
# Epoch 29/40
# 36/36 [==============================] - 30s 836ms/step - loss: 0.7244 - accuracy: 0.7193 - val_loss: 1.5695 - val_accuracy: 0.5684
# Epoch 30/40
# 36/36 [==============================] - 29s 816ms/step - loss: 0.7435 - accuracy: 0.7053 - val_loss: 1.2925 - val_accuracy: 0.5719
# Epoch 31/40
# 36/36 [==============================] - 30s 842ms/step - loss: 0.6956 - accuracy: 0.7351 - val_loss: 1.0803 - val_accuracy: 0.6105
# Epoch 32/40
# 36/36 [==============================] - 32s 876ms/step - loss: 0.6587 - accuracy: 0.7439 - val_loss: 1.0883 - val_accuracy: 0.6281
# Epoch 33/40
# 36/36 [==============================] - 30s 818ms/step - loss: 0.6371 - accuracy: 0.7439 - val_loss: 1.1261 - val_accuracy: 0.5965
# Epoch 34/40
# 36/36 [==============================] - 30s 819ms/step - loss: 0.6363 - accuracy: 0.7623 - val_loss: 1.5925 - val_accuracy: 0.5298
# Epoch 35/40
# 36/36 [==============================] - 30s 817ms/step - loss: 0.6481 - accuracy: 0.7526 - val_loss: 0.9583 - val_accuracy: 0.6421
# Epoch 36/40
# 36/36 [==============================] - 30s 823ms/step - loss: 0.5881 - accuracy: 0.7816 - val_loss: 1.7180 - val_accuracy: 0.5018
# Epoch 37/40
# 36/36 [==============================] - 30s 825ms/step - loss: 0.6066 - accuracy: 0.7860 - val_loss: 2.0978 - val_accuracy: 0.5158
# Epoch 38/40
# 36/36 [==============================] - 29s 816ms/step - loss: 0.5506 - accuracy: 0.7921 - val_loss: 1.2507 - val_accuracy: 0.5614
# Epoch 39/40
# 36/36 [==============================] - 30s 827ms/step - loss: 0.5662 - accuracy: 0.7798 - val_loss: 1.5710 - val_accuracy: 0.5965
# Epoch 40/40
# 36/36 [==============================] - 30s 818ms/step - loss: 0.5890 - accuracy: 0.7807 - val_loss: 1.4598 - val_accuracy: 0.5228
# 36/36 [==============================] - 7s 179ms/step - loss: 1.1234 - accuracy: 0.6219
# Validation Loss: 1.1234437227249146
# Validation Accuracy: 0.6219298243522644

# %%
evaluation = model.evaluate(val_ds)
print("Validation Loss:", evaluation[0])
print("Validation Accuracy:", evaluation[1])
# Out:
# 9/9 [==============================] - 2s 183ms/step - loss: 1.4407 - accuracy: 0.5509
# Validation Loss: 1.4407453536987305
# Validation Accuracy: 0.5508772134780884
